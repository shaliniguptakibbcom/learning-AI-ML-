# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.1.0'

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
X = np.array([1, 2, 5, 8, 12])
Y = np.array([3, 6, 7, 12, 9])

# %%
plt.plot(X, Y)

# %%
plt.show()

# %%
import numpy as np

X = np.array([1, 2, 5, 8, 12])
Y = np.array([3, 6, 7, 12, 9])

import matplotlib.pyplot as plt
plt.plot(X, Y)
plt.title("This is the title")
# Out:
# Text(0.5, 1.0, 'This is the title')

# %%
plt.xlabel("X label")
plt.ylabel("Y label")
# Out:
# Text(0, 0.5, 'Y label')

# %%
plt.show()

# %%
subjects = ["Maths", "Biology", "Chemistry", "Physics", "English", "Computers"]
marks = [97, 68, 59, 81, 77, 92]

# %%
plt.bar(subjects, marks, color='blue')
# Out:
# <BarContainer object of 6 artists>

# %%
subjects = ["Maths", "Biology", "Chemistry", "Physics", "English", "Computers"]
student1 = [97, 68, 59, 81, 77, 92]
student2 = [88, 61, 80, 40, 62, 52]
student3 = [54, 62, 77, 54, 71, 98]

# %%
index = np.arange(6)
width = 0.03

# %%
plt.bar(index, student1, width, color="aqua", label="Student 1")
plt.bar(index + width, student2, width, color="green", label="Student 2")
plt.bar(index + (width*2), student3, width, color="blue", label="Student 3")
# Out:
# <BarContainer object of 6 artists>

# %%
plt.title("Stacked Bar Graph Example")
plt.xlabel("Students")
plt.ylabel("Marks")
# Out:
# Text(0, 0.5, 'Marks')

# %%
plt.xticks(index + width/2, subjects)
# Out:
# ([<matplotlib.axis.XTick at 0x7f6fcc9dabe0>,
#   <matplotlib.axis.XTick at 0x7f6fcca530f0>,
#   <matplotlib.axis.XTick at 0x7f6fcc9f2940>,
#   <matplotlib.axis.XTick at 0x7f6fcc99d9b0>,
#   <matplotlib.axis.XTick at 0x7f6fcc99df28>,
#   <matplotlib.axis.XTick at 0x7f6fcc9a64e0>],
#  <a list of 6 Text xticklabel objects>)

# %%
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.show()

# %%
firms = ["Firm A", "Firm B", "Firm C", "Firm D", "Firm E"]
market_shares = [10, 40, 30, 5, 15]

# %%
Explode = [0, 0, 0, 0.5, 0]

# %%
plt.pie(market_shares, explode=Explode, labels=firms, shadow=True, startangle=45)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6fcc9529e8>,
#   <matplotlib.patches.Wedge at 0x7f6fcc8e4128>,
#   <matplotlib.patches.Wedge at 0x7f6fcc8e4828>,
#   <matplotlib.patches.Wedge at 0x7f6fcc8e4f28>,
#   <matplotlib.patches.Wedge at 0x7f6fcc8ef668>],
#  [Text(0.4993895451252888, 0.9801071789450159, 'Firm A'),
#   Text(-0.9801071906340715, 0.49938952218422455, 'Firm B'),
#   Text(0.17207800309356855, -1.0864571601546607, 'Firm C'),
#   Text(1.5216904874086232, -0.4944270022259173, 'Firm D'),
#   Text(1.0461621185951564, 0.3399188456330332, 'Firm E')])

# %%
plt.axis('equal')
plt.legend(title = "List of Firms")
# Out:
# No handles with labels found to put in legend.

# %%
x = np.random.randn(10000)

# %%
plt.title("Histogram Example")
plt.xlabel("Random Data")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(x, 10)
# Out:
# (array([8.000e+00, 1.130e+02, 6.140e+02, 1.844e+03, 2.987e+03, 2.731e+03,
#         1.305e+03, 3.500e+02, 4.700e+01, 1.000e+00]),
#  array([-3.86790618, -3.06740346, -2.26690075, -1.46639803, -0.66589531,
#          0.13460741,  0.93511012,  1.73561284,  2.53611556,  3.33661828,
#          4.137121  ]),
#  <a list of 10 Patch objects>)

# %%
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot

# %%
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# %%
figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
from numpy.random import rand

# %%
for color in ['red', 'green', 'blue']:
    n = 100
    x, y = rand(2, n)
    scale = 500.0 * rand(n) ** 5
    plt.scatter(x, y, s=scale, c=color, alpha=0.3, edgecolors='blue')

plt.grid(True)
plt.show()

# %%
len(x)
# Out:
# 100

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,4,7])

# %%
plt.subplot(2,1,1)
plt.plot(range(12))
plt.subplot(2,1,2, facecolor='red')
plt.plot(range(12))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
x = np.arange(0, math.pi*2, 0.09)
fig=plt.figure()
axes1 = fig.add_axes([.1, .1, .9, .9])
axes2 = fig.add_axes([2, 0.62, 0.3, 0.3])
y = np.sin(x)
axes1.plot(x, y, 'b')
axes2.plot(x,np.cos(x),'r')
axes1.set_title('sine')
axes2.set_title("cosine")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg

# %%
path = 'https://cloudxlab.s3.amazonaws.com/static/images/aha/matplotlib/introduction_image.png'
img = mpimg.imread(path)

# %%
imgplot = plt.imshow(img)
